# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanisha190405/AIML/blob/main/Experiment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 4:
# Write a python program to import and export data using Pandas and
# show the details of the dataset like number of rows, columns, first five
# rows, size, number of missing values, sum, average, min and max
# values from the numerical columns.

# %%
import pandas as pd

# %%
from google.colab import files

# %% [markdown]
# Uploading the file from system

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1937a811-3662-4473-b822-7de3cb2c138e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1937a811-3662-4473-b822-7de3cb2c138e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['student-dataset.csv']))

# %% [markdown]
# First five rows of the dataset

# %%
df.head(5)
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %% [markdown]
# Number of missing values in each column

# %%
df.isnull().sum()
# Out:
# id                      0
# name                    0
# nationality             0
# city                    0
# latitude                0
# longitude               0
# gender                  0
# ethnic.group          307
# age                     0
# english.grade           0
# math.grade              0
# sciences.grade          0
# language.grade          0
# portfolio.rating        0
# coverletter.rating      0
# refletter.rating        0
# dtype: int64

# %% [markdown]
# Number of rows

# %%
df.shape[0]
# Out:
# 307

# %% [markdown]
# Number of columns

# %%
df.shape[1]
# Out:
# 16

# %% [markdown]
# Size(Rows*columns)

# %%
df.size
# Out:
# 4912

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

# %% [markdown]
# Finding Sum in numerical columns

# %%
numerical_cols.sum()
# Out:
# id                    46971.00
# latitude              10089.06
# longitude            -19813.51
# ethnic.group              0.00
# age                    6743.00
# english.grade          1034.50
# math.grade             1048.20
# sciences.grade         1058.10
# language.grade         1349.70
# portfolio.rating       1224.00
# coverletter.rating     1262.00
# refletter.rating       1286.00
# dtype: float64

# %% [markdown]
# Finding Average in numerical columns

# %%
numerical_cols.mean()
# Out:
# id                    153.000000
# latitude               32.863388
# longitude             -64.539121
# ethnic.group                 NaN
# age                    21.964169
# english.grade           3.369707
# math.grade              3.414332
# sciences.grade          3.446580
# language.grade          4.396417
# portfolio.rating        3.986971
# coverletter.rating      4.110749
# refletter.rating        4.188925
# dtype: float64

# %% [markdown]
# Finding Minimum in numerical columns

# %%
numerical_cols.min()
# Out:
# id                      0.00
# latitude              -33.45
# longitude            -123.13
# ethnic.group             NaN
# age                    19.00
# english.grade           1.50
# math.grade              2.10
# sciences.grade          1.40
# language.grade          1.00
# portfolio.rating        1.00
# coverletter.rating      1.00
# refletter.rating        1.00
# dtype: float64

# %% [markdown]
# Finding maximum in numerical columns

# %%
numerical_cols.max()
# Out:
# id                    306.00
# latitude               59.89
# longitude             139.75
# ethnic.group             NaN
# age                    26.00
# english.grade           4.00
# math.grade              4.00
# sciences.grade          4.00
# language.grade          5.00
# portfolio.rating        5.00
# coverletter.rating      5.00
# refletter.rating        5.00
# dtype: float64
